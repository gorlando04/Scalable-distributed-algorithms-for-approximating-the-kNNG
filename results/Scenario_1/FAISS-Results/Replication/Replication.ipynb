# %% [markdown]
# Esses testes foram realizados utilizando 4 GPUs e o quantizador Padrão

# %% [markdown]
# # Importando as bibliotecas necessárias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Importando o dataset principal

# %%
#Importing dataset
df = pd.read_csv("replication.csv")
df.head()
# Out:
#    nprobe       Name   Method   Dim   N_sample   nList  DB Size (GB)  \
# 0     0.0  SK-1M-12d    brute  12.0  1000000.0     0.0         0.048
# 1     5.0  SK-1M-12d  ivfflat  12.0  1000000.0  4096.0         0.048
# 2    10.0  SK-1M-12d  ivfflat  12.0  1000000.0  4096.0         0.048
# 3    25.0  SK-1M-12d  ivfflat  12.0  1000000.0  4096.0         0.048
# 4    50.0  SK-1M-12d  ivfflat  12.0  1000000.0  4096.0         0.048
#
#    Time kNN  Recall@10     Total  Train time  Add time Erro  Move time
# 0  9.598725          -  9.598725         NaN       NaN  NaN        NaN
# 1  0.430006  0.3715344  3.540977    1.944657  1.166315  NaN        NaN
# 2  0.669890  0.5688079  3.535033    1.825114  1.040028  NaN        NaN
# 3  1.330519  0.8745657  4.323131    1.807993  1.184619  NaN        NaN
# 4  2.373800  0.9817824  5.517998    1.844121  1.300076  NaN        NaN

# %%
try:
    df.drop('Recall@-',axis=1,inplace=True)
except:
    print("Já removido")
# Out:
# Já removido

# %%
df.dtypes
# Out:
# nprobe          float64
# Name             object
# Method           object
# Dim             float64
# N_sample        float64
# nList           float64
# DB Size (GB)    float64
# Time kNN        float64
# Recall@10        object
# Total           float64
# Train time      float64
# Add time        float64
# Erro             object
# Move time       float64
# dtype: object

# %% [markdown]
# # Separando no dataset para o método bruto

# %%
#Getting the brute results
df_brute = df[df['Method'] == 'brute']
df_brute.head()
# Out:
#     nprobe        Name Method   Dim    N_sample  nList  DB Size (GB)  \
# 0      0.0   SK-1M-12d  brute  12.0   1000000.0    0.0         0.048
# 19     0.0  SK-10M-12d  brute  12.0  10000000.0    0.0         0.480
# 38     0.0  SK-20M-12d  brute  12.0  20000000.0    0.0         0.960
# 57     0.0  SK-30M-12d  brute  12.0  30000000.0    0.0         1.440
# 76     0.0  SK-40M-12d  brute  12.0  40000000.0    0.0         1.920
#
#         Time kNN Recall@10         Total  Train time  Add time Erro  Move time
# 0       9.598725         -      9.598725         NaN       NaN  NaN        NaN
# 19    881.312736         -    881.312736         NaN       NaN  NaN        NaN
# 38   3540.154815         -   3540.154815         NaN       NaN  NaN        NaN
# 57   7976.501085         -   7976.501085         NaN       NaN  NaN        NaN
# 76  20888.665000         -  20888.665000         0.0       0.0  NaN        0.0

# %% [markdown]
# # Separando no dataset para o método flat

# %%
#Getting the IVFFlat results
df_flat = df[df['Method'] == 'ivfflat']
df_flat
# Out:
#     nprobe        Name   Method   Dim    N_sample    nList  DB Size (GB)  \
# 1      5.0   SK-1M-12d  ivfflat  12.0   1000000.0   4096.0         0.048
# 2     10.0   SK-1M-12d  ivfflat  12.0   1000000.0   4096.0         0.048
# 3     25.0   SK-1M-12d  ivfflat  12.0   1000000.0   4096.0         0.048
# 4     50.0   SK-1M-12d  ivfflat  12.0   1000000.0   4096.0         0.048
# 5     75.0   SK-1M-12d  ivfflat  12.0   1000000.0   4096.0         0.048
# 6    100.0   SK-1M-12d  ivfflat  12.0   1000000.0   4096.0         0.048
# 20     5.0  SK-10M-12d  ivfflat  12.0  10000000.0  16384.0         0.480
# 21    10.0  SK-10M-12d  ivfflat  12.0  10000000.0  16384.0         0.480
# 22    25.0  SK-10M-12d  ivfflat  12.0  10000000.0  16384.0         0.480
# 23    50.0  SK-10M-12d  ivfflat  12.0  10000000.0  16384.0         0.480
# 24    75.0  SK-10M-12d  ivfflat  12.0  10000000.0  16384.0         0.480
# 25   100.0  SK-10M-12d  ivfflat  12.0  10000000.0  16384.0         0.480
# 39     5.0  SK-20M-12d  ivfflat  12.0  20000000.0  16384.0         0.960
# 40    10.0  SK-20M-12d  ivfflat  12.0  20000000.0  16384.0         0.960
# 41    25.0  SK-20M-12d  ivfflat  12.0  20000000.0  16384.0         0.960
# 42    50.0  SK-20M-12d  ivfflat  12.0  20000000.0  16384.0         0.960
# 43    75.0  SK-20M-12d  ivfflat  12.0  20000000.0  16384.0         0.960
# 44   100.0  SK-20M-12d  ivfflat  12.0  20000000.0  16384.0         0.960
# 58     5.0  SK-30M-12d  ivfflat  12.0  30000000.0  16384.0         1.440
# 59    10.0  SK-30M-12d  ivfflat  12.0  30000000.0  16384.0         1.440
# 60    25.0  SK-30M-12d  ivfflat  12.0  30000000.0  16384.0         1.440
# 61    50.0  SK-30M-12d  ivfflat  12.0  30000000.0  16384.0         1.440
# 62    75.0  SK-30M-12d  ivfflat  12.0  30000000.0  16384.0         1.440
# 63   100.0  SK-30M-12d  ivfflat  12.0  30000000.0  16384.0         1.440
# 77     5.0  SK-40M-12d  ivfflat  12.0  40000000.0  65536.0         1.920
#
#       Time kNN           Recall@10       Total  Train time   Add time  \
# 1     0.430006           0.3715344    3.540977    1.944657   1.166315
# 2     0.669890           0.5688079    3.535033    1.825114   1.040028
# 3     1.330519           0.8745657    4.323131    1.807993   1.184619
# 4     2.373800           0.9817824    5.517998    1.844121   1.300076
# 5     3.363997           0.9953888    6.283172    1.809944   1.109230
# 6     4.385422           0.9974406    7.228781    1.794939   1.048420
# 20    8.692132          0.35890395   38.397070   16.119184  13.585755
# 21   14.787446          0.54574378   43.632255   16.107395  12.737414
# 22   31.609494          0.84655957   61.760471   16.183013  13.967965
# 23   31.609494          0.84655957   61.760471   16.183013  13.967965
# 24   31.609494          0.84655957   61.760471   16.183013  13.967965
# 25   31.609494          0.84655957   61.760471   16.183013  13.967965
# 39   28.708550         0.390936585   65.129987   16.148676  20.272762
# 40   51.143287          0.59458863   88.414711   16.088141  21.183283
# 41  118.385561         0.885270835  155.073535   16.113989  20.573985
# 42  118.385561         0.885270835  155.073535   16.113989  20.573985
# 43  118.385561         0.885270835  155.073535   16.113989  20.573985
# 44  118.385561         0.885270835  155.073535   16.113989  20.573985
# 58   87.664928          0.41256834  133.231592   16.222789  29.343875
# 59  170.707541  0.6252571133333333  215.189697   16.038343  28.443813
# 60  170.707541  0.6252571133333333  215.189697   16.038343  28.443813
# 61  170.707541  0.6252571133333333  215.189697   16.038343  28.443813
# 62  170.707541  0.6252571133333333  215.189697   16.038343  28.443813
# 63  170.707541  0.6252571133333333  215.189697   16.038343  28.443813
# 77   51.459000              0.3297  411.333000    0.000000   0.000000
#
#                                                  Erro  Move time
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6                                                 NaN        NaN
# 20                                                NaN        NaN
# 21                                                NaN        NaN
# 22                                                NaN        NaN
# 23  Exception thrown from index 0: Error in virtua...        NaN
# 24  Exception thrown from index 0: Error in virtua...        NaN
# 25  Exception thrown from index 0: Error in virtua...        NaN
# 39                                                NaN        NaN
# 40                                                NaN        NaN
# 41                                                NaN        NaN
# 42  Exception thrown from index 0: Error in virtua...        NaN
# 43  Exception thrown from index 0: Error in virtua...        NaN
# 44  Exception thrown from index 0: Error in virtua...        NaN
# 58                                                NaN        NaN
# 59                                                NaN        NaN
# 60  Exception thrown from index 0: Error in virtua...        NaN
# 61  Exception thrown from index 0: Error in virtua...        NaN
# 62  Exception thrown from index 0: Error in virtua...        NaN
# 63  Exception thrown from index 0: Error in virtua...        NaN
# 77                                                NaN        0.0

# %% [markdown]
# # Separando para o método com o Product Quantization

# %%
#Getting the IVFPQ results
df_ivfpq = df[df['Method'] == 'ivfpq']
df_ivfpq
# Out:
#     nprobe        Name Method   Dim    N_sample    nList  DB Size (GB)  \
# 7      5.0   SK-1M-12d  ivfpq  12.0   1000000.0   4096.0         0.048
# 8     10.0   SK-1M-12d  ivfpq  12.0   1000000.0   4096.0         0.048
# 9     25.0   SK-1M-12d  ivfpq  12.0   1000000.0   4096.0         0.048
# 10    50.0   SK-1M-12d  ivfpq  12.0   1000000.0   4096.0         0.048
# 11    75.0   SK-1M-12d  ivfpq  12.0   1000000.0   4096.0         0.048
# 12   100.0   SK-1M-12d  ivfpq  12.0   1000000.0   4096.0         0.048
# 26     5.0  SK-10M-12d  ivfpq  12.0  10000000.0  16384.0         0.480
# 27    10.0  SK-10M-12d  ivfpq  12.0  10000000.0  16384.0         0.480
# 28    25.0  SK-10M-12d  ivfpq  12.0  10000000.0  16384.0         0.480
# 29    50.0  SK-10M-12d  ivfpq  12.0  10000000.0  16384.0         0.480
# 30    75.0  SK-10M-12d  ivfpq  12.0  10000000.0  16384.0         0.480
# 31   100.0  SK-10M-12d  ivfpq  12.0  10000000.0  16384.0         0.480
# 45     5.0  SK-20M-12d  ivfpq  12.0  20000000.0  16384.0         0.960
# 46    10.0  SK-20M-12d  ivfpq  12.0  20000000.0  16384.0         0.960
# 47    25.0  SK-20M-12d  ivfpq  12.0  20000000.0  16384.0         0.960
# 48    50.0  SK-20M-12d  ivfpq  12.0  20000000.0  16384.0         0.960
# 49    75.0  SK-20M-12d  ivfpq  12.0  20000000.0  16384.0         0.960
# 50   100.0  SK-20M-12d  ivfpq  12.0  20000000.0  16384.0         0.960
# 64     5.0  SK-30M-12d  ivfpq  12.0  30000000.0  16384.0         1.440
# 65    10.0  SK-30M-12d  ivfpq  12.0  30000000.0  16384.0         1.440
# 66    25.0  SK-30M-12d  ivfpq  12.0  30000000.0  16384.0         1.440
# 67    50.0  SK-30M-12d  ivfpq  12.0  30000000.0  16384.0         1.440
# 68    75.0  SK-30M-12d  ivfpq  12.0  30000000.0  16384.0         1.440
# 69   100.0  SK-30M-12d  ivfpq  12.0  30000000.0  16384.0         1.440
# 78     5.0  SK-40M-12d  ivfpq  12.0  40000000.0  65536.0         1.920
# 79    10.0  SK-40M-12d  ivfpq  12.0  40000000.0  65536.0         1.920
# 80    25.0  SK-40M-12d  ivfpq  12.0  40000000.0  65536.0         1.920
# 81    50.0  SK-40M-12d  ivfpq  12.0  40000000.0  65536.0         1.920
# 82    75.0  SK-40M-12d  ivfpq  12.0  40000000.0  65536.0         1.920
# 83   100.0  SK-40M-12d  ivfpq  12.0  40000000.0  65536.0         1.920
# 87     5.0  SK-50M-12d  ivfpq  12.0  50000000.0  65536.0         2.400
# 88    10.0  SK-50M-12d  ivfpq  12.0  50000000.0  65536.0         2.400
# 89    25.0  SK-50M-12d  ivfpq  12.0  50000000.0  65536.0         2.400
# 90    50.0  SK-50M-12d  ivfpq  12.0  50000000.0  65536.0         2.400
#
#       Time kNN           Recall@10       Total  Train time   Add time Erro  \
# 7     0.392316           0.3469769   19.245509   17.716123   1.137070  NaN
# 8     0.558754             0.51005   17.541098   15.819927   1.162417  NaN
# 9     1.028464           0.7384081   20.103770   17.625190   1.450116  NaN
# 10    1.709389           0.8137455   20.263239   17.398073   1.155777  NaN
# 11    2.406827           0.8235439   21.161880   17.559874   1.195179  NaN
# 12    3.130001           0.8250467   21.771366   17.441517   1.199848  NaN
# 26    5.501286          0.33369493   54.185853   34.882726  13.801841  NaN
# 27    8.029583          0.48618809   55.307703   32.802595  14.475525  NaN
# 28   13.516227          0.70469115   62.160421   34.654335  13.989859  NaN
# 29   25.240285          0.78687095   72.334332   33.061738  14.032310  NaN
# 30   34.598718          0.80048465   83.527106   34.828202  14.100186  NaN
# 31   51.951240          0.80322408  100.502349   33.141234  15.409875  NaN
# 45   12.950854          0.36217561   67.756375   32.933130  21.872391  NaN
# 46   18.332043         0.522981235   75.042639   33.733511  22.977085  NaN
# 47   33.536641          0.72249623   88.814835   32.925024  22.353170  NaN
# 48   59.330647         0.782023735  115.473906   32.254840  23.888418  NaN
# 49   82.060800          0.78966176  137.205162   33.008858  22.135504  NaN
# 50  106.691191          0.79089297  160.609059   32.971805  20.946064  NaN
# 64   29.557325          0.38038437   93.945730   33.437078  30.951327  NaN
# 65   66.729221          0.54456146  129.032238   32.429894  29.873122  NaN
# 66  129.044256  0.7312552933333333  192.594001   33.917788  29.631957  NaN
# 67  227.032555  0.7796519533333334  290.168278   33.516538  29.619185  NaN
# 68  319.253931          0.78495719  379.269483   30.614478  29.401074  NaN
# 69  411.515784  0.7857023333333333  473.073783   32.677857  28.880141  NaN
# 78   40.492000               0.306  427.827000    0.000000   0.000000  NaN
# 79   69.742000              0.4405  456.510000    0.000000   0.000000  NaN
# 80  149.880000              0.6496  538.860000    0.000000   0.000000  NaN
# 81  262.760000              0.7469  649.452000    0.000000   0.000000  NaN
# 82  357.470000              0.7689  745.733000    0.000000   0.000000  NaN
# 83  457.320000               0.775  846.285000    0.000000   0.000000  NaN
# 87   50.650000              0.3143  461.232000    0.000000   0.000000  NaN
# 88   64.911000               0.451  477.091000    0.000000   0.000000  NaN
# 89   96.271000               0.655  506.902000    0.000000   0.000000  NaN
# 90  148.590000               0.744  564.148000    0.000000   0.000000  NaN
#
#     Move time
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 50        NaN
# 64        NaN
# 65        NaN
# 66        NaN
# 67        NaN
# 68        NaN
# 69        NaN
# 78        0.0
# 79        0.0
# 80        0.0
# 81        0.0
# 82        0.0
# 83        0.0
# 87        0.0
# 88        0.0
# 89        0.0
# 90        0.0

# %% [markdown]
# # Plotando Gráficos

# %%
df_g = df[df['Erro'].isna()]

# %%
df_g = df_g[df_g['Method'] != 'brute']

# %% [markdown]
# ## Training

# %%
import math
def nlist(n):
    y = int( 2 ** ( 2 * round(math.log(n,10)) ) )
    return y

y = np.vectorize(nlist)
x = [int(1e6),int(1e7),int(2e7),int(3e7),int(4e7),int(5e7)]
plt.plot(x
,y(x),marker='o',markersize=8,markerfacecolor='black',markeredgecolor='black',linestyle='-'
)


x = [int(1e6),int(10e6),int(20e6),int(30e6),int(40e6),int(50e6)]
labels = ['SK-1M', 'SK-10M', 'SK-20M', 'SK-30M',
   'SK-40M', 'SK-50M']
plt.xticks(x, labels)

plt.xlabel('Number of samples')

plt.ylabel(f"Number of partitions")
plt.title(f'Partitions for N_samples')
plt.grid('on')



plt.show()

# %% [markdown]
# ## Função para plotar gráfico do dataframe

# %%
nprobes = df[(df['Method'] == 'ivfflat') & (df['Name'] == 'SK-50M-12d')]['nprobe'].unique()

# %%
len(nprobes)
# Out:
# 0

# %%
def plot_2df(df,db,col):
    
    try:
        df = df.astype({"Time kNN": float, "Recall@10": float})
    except:
        print("O que aconteceu")
        pass
    colors = ['red','green','orchid']

    methods = ['ivfflat','ivfpq','ivfsq']
    
    fig = plt.figure(figsize=[7,5])

    
    
    for index,method in enumerate(methods):
        nprobes = df[(df['Method'] == method) & (df['Name'] == db)]['nprobe'].unique()
        
        if len(nprobes) > 0:
            plt.plot(nprobes,df[(df['Method'] == method) & (df['Name'] == db)][col],
                label=method.upper(),marker='o',markersize=8,color=colors[index],markerfacecolor='black',
                markeredgecolor='black',linestyle='-'
            )


    



    plt.legend(loc ="lower right")

    x = [5,10,25,50,75,100]
    labels = x
    plt.xticks(x, labels)
    
    plt.xlabel('Nprobes')
    string = ''
    if col != 'Recall@10':
        string = ' (s)'
    plt.ylabel(f"{col}{string}")
    plt.title(f'{db}')
    plt.grid('on')
    


    plt.show()

# %% [markdown]
# ## Gráfico do Brute

# %%
def plot_brute(df):
    df = df.astype({"Time kNN": float,"N_sample": int})
    plt.plot(df['N_sample'],df['Time kNN']
        ,marker='o',markersize=8,color='red',markerfacecolor='black',
        markeredgecolor='black',linestyle='-'
    )
    
    plt.title(f' Brute method')
    plt.ylabel('Time kNN (s)')
    plt.xlabel('N sample')
    
    
    
plot_brute(df_brute)

# %% [markdown]
# ## Gráficos

# %% [markdown]
# ### 1 MILHAO

# %%
plot_2df(df_g,'SK-1M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-1M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-1M-12d','Total')

# %% [markdown]
# ### 10 MILHÃO

# %%
plot_2df(df_g,'SK-10M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-10M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-10M-12d','Total')

# %% [markdown]
# ### 20 MILHÃO

# %%
plot_2df(df_g,'SK-20M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-20M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-20M-12d','Total')

# %% [markdown]
# ### 30 MILHÃO

# %%
plot_2df(df_g,'SK-30M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-30M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-30M-12d','Total')

# %% [markdown]
# ### 40 MILHÃO

# %%
plot_2df(df_g,'SK-40M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-40M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-40M-12d','Total')

# %% [markdown]
# ### 50 MILHÃO

# %%
plot_2df(df_g,'SK-50M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-50M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-50M-12d','Total')

# %%
time_pq = {}
time_ff = {}
n = [int(1e6),int(1e7),int(2e7),int(3e7),int(4e7),int(5e7)]

# %%
method = 'ivfpq'

nprobes = [5,10,25,50,75,100]
for i in nprobes:
    aux = df_g[(df_g['Method'] == method) & (df_g['nprobe'] == i)]['Time kNN'].values
    time_pq[str(i)] = list(aux)

# %%
method = 'ivfflat'

nprobes = [5,10,25,50,75,100]
for i in nprobes:
    aux = df_g[(df_g['Method'] == method) & (df_g['nprobe'] == i)]['Time kNN'].values
    time_ff[str(i)] = list(aux)

# %%
def complexidade(t0,n0,tf,nf):
    import math
    b = tf / t0
    a = nf / n0
    
    x = math.log(b,a)
    return x

# %%
time_pq['5']
# Out:
# [0.3923161029815674,
#  5.501286268234253,
#  12.9508535861969,
#  29.55732488632202,
#  40.492,
#  50.65]

# %%
for j in ['5','10','25','50','75','100']:
    for index,val in enumerate(time_pq[j]):
        if index == 0:
            continue

        t0 = float(time_pq[j][index-1])
        n0 = n[index-1]

        tf = float(val)
        nf = n[index]

        comp = complexidade(t0,n0,tf,nf)
        print(f"{index} -> Complexidae; {comp}")
    print("\n\n\n")
# Out:
# 1 -> Complexidae; 1.1468281102273117
# 2 -> Complexidae; 1.2352063055730973
# 3 -> Complexidae; 2.0351193672699246
# 4 -> Complexidae; 1.0941690833404027
# 5 -> Complexidae; 1.0030978069494105
#
#
#
#
# 1 -> Complexidae; 1.157472370694651
# 2 -> Complexidae; 1.190970583468663
# 3 -> Complexidae; 3.1864454836538423
# 4 -> Complexidae; 0.15350195552313264
# 5 -> Complexidae; -0.32170151226317845
#
#
#
#
# 1 -> Complexidae; 1.1186663571400266
# 2 -> Complexidae; 1.3110456805068664
# 3 -> Complexidae; 3.323385394149224
# 4 -> Complexidae; 0.5202950455890982
# 5 -> Complexidae; -1.9837805759140195
#
#
#
#
# 1 -> Complexidae; 1.169253234254031
# 2 -> Complexidae; 1.2330493250751582
# 3 -> Complexidae; 3.309698922712647
# 4 -> Complexidae; 0.5080179174126657
# 5 -> Complexidae; -2.5546345811863724
#
#
#
#
# 1 -> Complexidae; 1.1576150471440798
# 2 -> Complexidae; 1.245974646925419
# 3 -> Complexidae; 3.3505382987447265
# 4 -> Complexidae; 0.3930193984581379
#
#
#
#
# 1 -> Complexidae; 1.2200514347575986
# 2 -> Complexidae; 1.0382109625735605
# 3 -> Complexidae; 3.329284706775843
# 4 -> Complexidae; 0.3668493713306409
