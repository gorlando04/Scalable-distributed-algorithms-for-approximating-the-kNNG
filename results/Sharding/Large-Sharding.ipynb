# %% [markdown]
# # Importando as bibliotecas necessárias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Importando o dataset principal

# %%
#Importing dataset
df = pd.read_csv("large_sharding.csv")
df.head()
# Out:
#           Name Method   Dim     N_sample    nList  nprobe  DB Size (GB)  \
# 0  SK-100M-12d  brute  12.0  100000000.0      0.0     0.0           4.8
# 1  SK-100M-12d  ivfpq  12.0  100000000.0  65536.0     5.0           4.8
# 2  SK-100M-12d  ivfpq  12.0  100000000.0  65536.0    10.0           4.8
# 3  SK-100M-12d  ivfpq  12.0  100000000.0  65536.0    25.0           4.8
# 4  SK-100M-12d  ivfpq  12.0  100000000.0  65536.0    50.0           4.8
#
#         Total    Time kNN Recall@10  Train time    Add time  Move time
# 0   31.078460   31.078460         -         NaN         NaN        NaN
# 1  615.768651  232.112546   0.36287  264.986485  101.652754  17.016865
# 2  711.621381  327.965276   0.51524  264.986485  101.652754  17.016865
# 3  857.343159  473.687054   0.70793  264.986485  101.652754  17.016865
# 4  956.109308  572.453204   0.77549  264.986485  101.652754  17.016865

# %%
df.dtypes
# Out:
# Name             object
# Method           object
# Dim             float64
# N_sample        float64
# nList           float64
# nprobe          float64
# DB Size (GB)    float64
# Total           float64
# Time kNN        float64
# Recall@10        object
# Train time      float64
# Add time        float64
# Move time       float64
# dtype: object

# %% [markdown]
# # Separando no dataset para o método bruto

# %%
#Getting the brute results
df_brute = df[df['Method'] == 'brute']
df_brute.head()
# Out:
#            Name Method   Dim     N_sample  nList  nprobe  DB Size (GB)  \
# 0   SK-100M-12d  brute  12.0  100000000.0    0.0     0.0           4.8
# 7   SK-200M-12d  brute  12.0  200000000.0    0.0     0.0           9.6
# 14  SK-300M-12d  brute  12.0  300000000.0    0.0     0.0          14.4
# 21  SK-400M-12d  brute  12.0  400000000.0    0.0     0.0          19.2
#
#          Total    Time kNN Recall@10  Train time  Add time  Move time
# 0    31.078460   31.078460         -         NaN       NaN        NaN
# 7    60.321425   60.321425         -         NaN       NaN        NaN
# 14   89.841442   89.841442         -         NaN       NaN        NaN
# 21  116.782773  116.782773         -         NaN       NaN        NaN

# %% [markdown]
# # Plotando Gráficos

# %%
df_g = df[df['Method'] != 'brute']

# %% [markdown]
# ## Training

# %%
import math
def nlist(n):
    y = int( 2 ** ( 2 * round(math.log(n,10)) ) )
    return y

y = np.vectorize(nlist)
x = [int(1e8),int(2e8),int(3e8),int(4e8)]
plt.plot(x
,y(x),marker='o',markersize=8,markerfacecolor='black',markeredgecolor='black',linestyle='-'
)


x = [int(1e8),int(2e8),int(3e8),int(4e8)]
labels = ['SK-100M', 'SK-200M', 'SK-300M', 'SK-400M']
plt.xticks(x, labels)

plt.xlabel('Number of samples')

plt.ylabel(f"Number of partitions")
plt.title(f'Partitions for N_samples')
plt.grid('on')



plt.show()

# %%
def plot_train(df_list,col,method):
    


    
    colors = ['green']
    
    methods = ['ivfpq']
    
    aux = df.drop_duplicates(subset=['Name','Method'],keep='first')
    
    fig = plt.figure(figsize=[7,5])

    
    for index,method in enumerate(methods):
        

        plt.plot(aux[aux['Method'] == method]['N_sample'],aux[aux['Method'] == method]['Train time'],
            label=f"{method.upper()}",marker='o',markersize=8,color=colors[index],markerfacecolor='black',
            markeredgecolor='black',linestyle='-'
        )


    


    
    plt.legend(loc ="lower right")
    plt.title(f'Training time')
    plt.ylabel("Time to train (s)")
    plt.xlabel('N_sample')
    x = [int(1e8),int(2e8),int(3e8),int(4e8)]
    labels = ['SK-100M', 'SK-200M', 'SK-300M', 'SK-400M']
    plt.xticks(x, labels)
    
    plt.grid('on')

    plt.show()

# %%
plot_train(df_g,'-','-')

# %% [markdown]
# ## Função para plotar gráfico do dataframe

# %%
def plot_2df(df,db,col):
    
    try:
        df = df.astype({"Time kNN": float, "Recall@10": float})
    except:
        pass
    colors = ['green']

    methods = ['ivfpq']
    
    fig = plt.figure(figsize=[7,5])

    
    
    for index,method in enumerate(methods):
        nprobes = df[(df['Method'] == method) & (df['Name'] == db)]['nprobe'].unique()
        
        plt.plot(nprobes,df[(df['Method'] == method) & (df['Name'] == db)][col],
            label=method.upper(),marker='o',markersize=8,color=colors[index],markerfacecolor='black',
            markeredgecolor='black',linestyle='-'
        )


    



    plt.legend(loc ="lower right")

    x = [5,10,25,50,75,100]
    labels = x
    plt.xticks(x, labels)
    
    plt.xlabel('Nprobes')
    string = ''
    if col != 'Recall@10':
        string = ' (s)'
    plt.ylabel(f"{col}{string}")
    plt.title(f'{db}')
    plt.grid('on')
    


    plt.show()

# %% [markdown]
# ## Gráfico do Brute

# %%
def plot_brute(df):
    df = df.astype({"Time kNN": float,"N_sample": int})
    plt.plot(df['N_sample'],df['Time kNN']
        ,marker='o',markersize=8,color='red',markerfacecolor='black',
        markeredgecolor='black',linestyle='-'
    )
    
    plt.title(f' Brute method')
    plt.ylabel('Time kNN (s)')
    plt.xlabel('N sample')
    
    
    
plot_brute(df_brute)

# %% [markdown]
# ## Gráficos

# %% [markdown]
# ### 100 Million

# %%
plot_2df(df_g,'SK-100M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-100M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-100M-12d','Total')

# %% [markdown]
# ### 200 MILLION

# %%
plot_2df(df_g,'SK-200M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-200M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-200M-12d','Total')

# %% [markdown]
# ### 300 MILLION

# %%
plot_2df(df_g,'SK-300M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-300M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-300M-12d','Total')

# %% [markdown]
# ### 400 MILLION

# %%
plot_2df(df_g,'SK-400M-12d','Time kNN')

# %%
plot_2df(df_g,'SK-400M-12d','Recall@10')

# %%
plot_2df(df_g,'SK-400M-12d','Total')
